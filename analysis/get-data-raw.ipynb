# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.debugger import set_trace
import json
from matplotlib import colors
from ast import literal_eval

# %% [markdown]
# # Load data

# %%
# psynet 11
fname = "manu-test-ising1"
fname = "singing-musicians-June-2026"

PATH = f"data/{fname}/"
nodes = pd.read_csv(PATH + "CustomNode.csv", low_memory=False)
# networks = pd.read_csv(PATH + "CustomNetwork.csv", low_memory=False) # old psynet
trials = pd.read_csv(PATH + "CustomTrial.csv", low_memory=False)

# %%
print(nodes)
# Out:
#      vars    id        creation_time  failed  failed_reason  time_of_death  \
# 0      {}    17  2026-05-12 13:20:05   False            NaN            NaN
# 1      {}    18  2026-05-12 13:20:05   False            NaN            NaN
# 2      {}    19  2026-05-12 13:20:05   False            NaN            NaN
# 3      {}    20  2026-05-12 13:20:05   False            NaN            NaN
# 4      {}    21  2026-05-12 13:20:05   False            NaN            NaN
# ...   ...   ...                  ...     ...            ...            ...
# 1100   {}  1117  2026-06-05 13:43:44   False            NaN            NaN
# 1101   {}  1118  2026-06-05 13:43:56   False            NaN            NaN
# 1102   {}  1119  2026-06-05 13:44:09   False            NaN            NaN
# 1103   {}  1120  2026-06-05 13:44:21   False            NaN            NaN
# 1104   {}  1121  2026-06-05 13:44:33   False            NaN            NaN
#
#              type  network_id  participant_id   trial_maker_id  ... parent_id  \
# 0     TrialSource          17               3  imitation_chain  ...       NaN
# 1     TrialSource          18               3  imitation_chain  ...       NaN
# 2     TrialSource          19               3  imitation_chain  ...       NaN
# 3     TrialSource          20               3  imitation_chain  ...       NaN
# 4     TrialSource          21               3  imitation_chain  ...       NaN
# ...           ...         ...             ...              ...  ...       ...
# 1100   CustomNode         141              32  imitation_chain  ...    1114.0
# 1101   CustomNode         137              32  imitation_chain  ...    1112.0
# 1102   CustomNode         141              32  imitation_chain  ...    1117.0
# 1103   CustomNode         138              32  imitation_chain  ...    1113.0
# 1104   CustomNode         139              32  imitation_chain  ...    1116.0
#
#                                                    seed  \
# 0     {"register": "high", "reference_pitch": 59.731...
# 1     {"register": "high", "reference_pitch": 60.941...
# 2     {"register": "high", "reference_pitch": 61.414...
# 3     {"register": "high", "reference_pitch": 62.112...
# 4     {"register": "high", "reference_pitch": 63.022...
# ...                                                 ...
# 1100  {"reference_pitch": 63.44152376139428, "regist...
# 1101  {"reference_pitch": 61.06483482990719, "regist...
# 1102  {"reference_pitch": 60.379981549785235, "regis...
# 1103  {"reference_pitch": 59.10388903547433, "regist...
# 1104  {"reference_pitch": 59.53336152758012, "regist...
#
#                                              definition  context  \
# 0     {"register": "high", "reference_pitch": 59.731...      NaN
# 1     {"register": "high", "reference_pitch": 60.941...      NaN
# 2     {"register": "high", "reference_pitch": 61.414...      NaN
# 3     {"register": "high", "reference_pitch": 62.112...      NaN
# 4     {"register": "high", "reference_pitch": 63.022...      NaN
# ...                                                 ...      ...
# 1100  {"reference_pitch": 63.44152376139428, "regist...      NaN
# 1101  {"reference_pitch": 61.06483482990719, "regist...      NaN
# 1102  {"reference_pitch": 60.379981549785235, "regis...      NaN
# 1103  {"reference_pitch": 59.10388903547433, "regist...      NaN
# 1104  {"reference_pitch": 59.53336152758012, "regist...      NaN
#
#       participant_group    block  propagate_failure  n_viable_trials  \
# 0               default  default              False                1
# 1               default  default              False                1
# 2               default  default              False                1
# 3               default  default              False                1
# 4               default  default              False                1
# ...                 ...      ...                ...              ...
# 1100            default  default              False                1
# 1101            default  default              False                0
# 1102            default  default              False                0
# 1103            default  default              False                0
# 1104            default  default              False                0
#
#            class  object_type
# 0     CustomNode         Node
# 1     CustomNode         Node
# 2     CustomNode         Node
# 3     CustomNode         Node
# 4     CustomNode         Node
# ...          ...          ...
# 1100  CustomNode         Node
# 1101  CustomNode         Node
# 1102  CustomNode         Node
# 1103  CustomNode         Node
# 1104  CustomNode         Node
#
# [1105 rows x 33 columns]

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])
node_data["definition"].iloc[1]

print(node_data['definition'])
# Out:
# 0       {"register": "high", "reference_pitch": 59.731...
# 9       {"reference_pitch": 61.08291241563504, "regist...
# 11      {"reference_pitch": 60.52760335449275, "regist...
# 17      {"reference_pitch": 61.49649891433537, "regist...
# 23      {"reference_pitch": 61.37479592370528, "regist...
#                               ...
# 1086    {"reference_pitch": 58.89304522331387, "regist...
# 1091    {"reference_pitch": 59.842475128342, "register...
# 1097    {"reference_pitch": 61.62411243945739, "regist...
# 1100    {"reference_pitch": 63.44152376139428, "regist...
# 1102    {"reference_pitch": 60.379981549785235, "regis...
# Name: definition, Length: 1105, dtype: object

# %% [markdown]
# # Preprocess data

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])

# process node definition
mel_id = []
# register = []
trial_type = []
target_pitches = []
target_intervals = []
reference_pitch = []
target_note_durations = []

for i in range(len(node_data)):
    print()
    # definition = node_data["definition"].to_numpy()[i]
    # definition = literal_eval(definition)
    # definition = [d["content"] for d in definition if d["is_center"]][0]

    definition_str = node_data["definition"].iloc[i]  # Access the string directly
    print(definition_str)
    definition = json.loads(definition_str)  # Parse JSON string into dictionary
    # definition = [d["content"] for d in definition if d["is_center"]][0]
    
    # mel_id.append(definition["mel_id"])
    # register.append(definition["register"])
    trial_type.append(definition["trial_type"])
    target_pitches.append(definition["target_pitches"])
    reference_pitch.append(definition["reference_pitch"])
    target_intervals.append(definition["target_intervals"])

# node_data["mel_id"] = mel_id
# node_data["register"] = register
node_data["trial_type"] = trial_type
node_data["target_pitches"] = target_pitches
node_data["reference_pitch"] = reference_pitch
node_data["target_intervals"] = target_intervals
# Out:
# {"register": "high", "reference_pitch": 59.731018325479795, "max_interval2reference": 10, "max_interval_size": 5.5, "target_pitches": [53.68399922936616, 57.40811868578826, 57.05767002267592], "target_intervals": [3.724119456422102, -0.35044866311233847], "target_intervals2reference": [-6.047019096113637, -2.322899639691535, -2.6733483028038734], "num_target_pitches": 3, "trial_type": "source_trial", "reference_mode": "pitch_mode"}
#
# {"reference_pitch": 61
"num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 63.44152376139428, "register": "high", "target_pitches": [62.16830843665183, 57.218638785203595, 56.80240897800143], "target_intervals": [-4.949669651448232, -0.4162298072021642], "target_intervals2reference": [-1.273215324742452, -6.222884976190684, -6.6391147833928486], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 60.379981549785235, "register": "high", "target_pitches": [59.138663695538774, 54.423419143398824, 53.270451054857865], "target_intervals": [-4.71524455213995, -1.152968088540959], "target_intervals2reference": [-1.2413178542464607, -5.956562406386411, -7.10953049492737], "num_target_pitches": 3, "trial_type": "node_trial"}

# %%
node_data
# Out:
#         id  network_id  degree   trial_maker_id  \
# 0       17          17       0  imitation_chain
# 9       26          17       1  imitation_chain
# 11      28          17       2  imitation_chain
# 17      34          17       3  imitation_chain
# 23      40          17       4  imitation_chain
# ...    ...         ...     ...              ...
# 1086  1103         141       6  imitation_chain
# 1091  1108         141       7  imitation_chain
# 1097  1114         141       8  imitation_chain
# 1100  1117         141       9  imitation_chain
# 1102  1119         141      10  imitation_chain
#
#                                              definition  \
# 0     {"register": "high", "reference_pitch": 59.731...
# 9     {"reference_pitch": 61.08291241563504, "regist...
# 11    {"reference_pitch": 60.52760335449275, "regist...
# 17    {"reference_pitch": 61.49649891433537, "regist...
# 23    {"reference_pitch": 61.37479592370528, "regist...
# ...                                                 ...
# 1086  {"reference_pitch": 58.89304522331387, "regist...
# 1091  {"reference_pitch": 59.842475128342, "register...
# 1097  {"reference_pitch": 61.62411243945739, "regist...
# 1100  {"reference_pitch": 63.44152376139428, "regist...
# 1102  {"reference_pitch": 60.379981549785235, "regis...
#
#                                                    seed    trial_type  \
# 0     {"register": "high", "reference_pitch": 59.731...  source_trial
# 9     {"reference_pitch": 61.08291241563504, "regist...    node_trial
# 11    {"reference_pitch": 60.52760335449275, "regist...    node_trial
# 17    {"reference_pitch": 61.49649891433537, "regist...    node_trial
# 23    {"reference_pitch": 61.37479592370528, "regist...    node_trial
# ...                                                 ...           ...
# 1086  {"reference_pitch": 58.89304522331387, "regist...    node_trial
# 1091  {"reference_pitch": 59.842475128342, "register...    node_trial
# 1097  {"reference_pitch": 61.62411243945739, "regist...    node_trial
# 1100  {"reference_pitch": 63.44152376139428, "regist...    node_trial
# 1102  {"reference_pitch": 60.379981549785235, "regis...    node_trial
#
#                                          target_pitches  reference_pitch  \
# 0     [53.68399922936616, 57.40811868578826, 57.0576...        59.731018
# 9     [55.27080518097104, 59.05203125066438, 58.3216...        61.082912
# 11    [55.102270938473566, 58.314846963992494, 57.10...        60.527603
# 17    [56.39892078508289, 59.56488597569569, 58.4046...        61.496499
# 23    [56.08071294651859, 59.3833862730152, 58.35594...        61.374796
# ...                                                 ...              ...
# 1086  [57.80033692039233, 52.61737193396052, 51.7999...        58.893045
# 1091  [58.78337548301649, 53.60398925902839, 52.7028...        59.842475
# 1097  [60.45838719545648, 55.43485407387196, 54.5156...        61.624112
# 1100  [62.16830843665183, 57.218638785203595, 56.802...        63.441524
# 1102  [59.138663695538774, 54.423419143398824, 53.27...        60.379982
#
#                                target_intervals
# 0     [3.724119456422102, -0.35044866311233847]
# 9     [3.7812260696933393, -0.7303914005979664]
# 11    [3.2125760255189277, -1.2131111694168766]
# 17      [3.165965190612795, -1.160252349485141]
# 23    [3.3026733264966097, -1.0274393154163235]
# ...                                         ...
# 1086  [-5.182964986431813, -0.8174685580957615]
# 1091  [-5.179386223988104, -0.9011604184889848]
# 1097  [-5.023533121584521, -0.9191648230793916]
# 1100  [-4.949669651448232, -0.4162298072021642]
# 1102    [-4.71524455213995, -1.152968088540959]
#
# [1105 rows x 10 columns]

# %% [markdown]
# # Export node data to csv

# %%
node_data.to_csv(f"{fname}_node_data.csv")

# %% [markdown]
# # Trial level data

# %%
# filter trials
trial_data = trials
trial_data = trial_data[trial_data["failed"] == False]

degrees = []

for i in range(len(trial_data)):
    current_node_id = trial_data.iloc[i]["origin_id"]
    current_nodes = node_data[node_data["id"] == current_node_id]
    current_degree = current_nodes["degree"].to_numpy()[0]
    # answer = d['listen_and_rate_trial_seed']['valence']
    # current_vertex_id = current_nodes["vertex_id"].to_numpy()[0]
    # current_dependent_vertex_ids = current_nodes["dependent_vertex_ids"].to_numpy()[0]
    degrees.append(current_degree)
    # vertex_ids.append(current_vertex_id)
    # dependent_vertex_ids.append(current_dependent_vertex_ids)

trial_data["degree"] = degrees

trial_data = trial_data[["id", "network_id", "degree", "trial_maker_id", "origin_id", "participant_id", "analysis"]]
trial_data = trial_data.sort_values(["network_id", "degree"])
# Out:
# /var/folders/v7/s8wj18ld78gdbf0vgx1ptf7r0000gr/T/ipykernel_13294/4239617211.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_data["degree"] = degrees

# %%
trial_data
# Out:
#         id  network_id  degree   trial_maker_id  origin_id  participant_id  \
# 4       17          17       0  imitation_chain         17               3
# 6       19          17       1  imitation_chain         26               3
# 12      25          17       2  imitation_chain         28               3
# 18      31          17       3  imitation_chain         34               3
# 20      33          17       4  imitation_chain         40               3
# ...    ...         ...     ...              ...        ...             ...
# 1274  1560         141       5  imitation_chain       1097              32
# 1279  1565         141       6  imitation_chain       1103              32
# 1287  1573         141       7  imitation_chain       1108              32
# 1290  1576         141       8  imitation_chain       1114              32
# 1292  1578         141       9  imitation_chain       1117              32
#
#                                                analysis
# 4     {"failed": false, "reason": "All good", "regis...
# 6     {"failed": false, "reason": "All good", "regis...
# 12    {"failed": false, "reason": "All good", "regis...
# 18    {"failed": false, "reason": "All good", "regis...
# 20    {"failed": false, "reason": "All good", "regis...
# ...                                                 ...
# 1274  {"failed": false, "reason": "All good", "regis...
# 1279  {"failed": false, "reason": "All good", "regis...
# 1287  {"failed": false, "reason": "All good", "regis...
# 1290  {"failed": false, "reason": "All good", "regis...
# 1292  {"failed": false, "reason": "All good", "regis...
#
# [972 rows x 7 columns]

# %% [markdown]
# # Export trial data to csv

# %%
trial_data.to_csv(f"{fname}_trial_data.csv")

# %% [markdown]
# # Experiment Cost and Demographics

# %%
participants = pd.read_csv(PATH + "participant.csv", low_memory=False)

# %%
valid_participants = participants[participants["complete"] == True]
valid_participants = valid_participants[valid_participants["failed"] == False]
experiment_summary = {
    "N_participants": valid_participants.shape[0],
    "cost": participants["base_pay"].sum() + participants["bonus"].sum()
}

experiment_summary
# Out:
# {'N_participants': 24, 'cost': 0.0}
