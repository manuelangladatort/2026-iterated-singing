# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.debugger import set_trace
import json
from matplotlib import colors
from ast import literal_eval

# %% [markdown]
# # Load data

# %%
# psynet 11
fname = "manu-test-ising1"

PATH = f"data/{fname}/"
nodes = pd.read_csv(PATH + "CustomNode.csv", low_memory=False)
# networks = pd.read_csv(PATH + "CustomNetwork.csv", low_memory=False) # old psynet
trials = pd.read_csv(PATH + "CustomTrial.csv", low_memory=False)

# %%
print(nodes)
# Out:
#     vars   id        creation_time  failed  failed_reason  time_of_death  \
# 0     {}   17  2026-04-28 17:15:13   False            NaN            NaN
# 1     {}   18  2026-04-28 17:15:13   False            NaN            NaN
# 2     {}   19  2026-04-28 17:15:13   False            NaN            NaN
# 3     {}   20  2026-04-28 17:15:13   False            NaN            NaN
# 4     {}   21  2026-04-28 17:15:13   False            NaN            NaN
# ..   ...  ...                  ...     ...            ...            ...
# 759   {}  776  2026-04-30 09:13:23   False            NaN            NaN
# 760   {}  777  2026-04-30 09:13:41   False            NaN            NaN
# 761   {}  778  2026-04-30 09:13:50   False            NaN            NaN
# 762   {}  779  2026-04-30 09:13:59   False            NaN            NaN
# 763   {}  780  2026-04-30 09:14:07   False            NaN            NaN
#
#             type  network_id  participant_id   trial_maker_id  ... parent_id  \
# 0    TrialSource          17               2  imitation_chain  ...       NaN
# 1    TrialSource          18               2  imitation_chain  ...       NaN
# 2    TrialSource          19               2  imitation_chain  ...       NaN
# 3    TrialSource          20               2  imitation_chain  ...       NaN
# 4    TrialSource          21               2  imitation_chain  ...       NaN
# ..           ...         ...             ...              ...  ...       ...
# 759   CustomNode         101              23  imitation_chain  ...     771.0
# 760   CustomNode          99              23  imitation_chain  ...     773.0
# 761   CustomNode         100              23  imitation_chain  ...     772.0
# 762   CustomNode          97              23  imitation_chain  ...     775.0
# 763   CustomNode          98              23  imitation_chain  ...     774.0
#
#                                                   seed  \
# 0    {"register": "high", "reference_pitch": 63.455...
# 1    {"register": "high", "reference_pitch": 62.147...
# 2    {"register": "high", "reference_pitch": 61.456...
# 3    {"register": "high", "reference_pitch": 59.796...
# 4    {"register": "high", "reference_pitch": 61.077...
# ..                                                 ...
# 759  {"reference_pitch": 58.50323955755315, "regist...
# 760  {"reference_pitch": 63.22744278433368, "regist...
# 761  {"reference_pitch": 62.02083459806798, "regist...
# 762  {"reference_pitch": 60.46645306886603, "regist...
# 763  {"reference_pitch": 61.2755138541487, "registe...
#
#                                             definition  context  \
# 0    {"register": "high", "reference_pitch": 63.455...      NaN
# 1    {"register": "high", "reference_pitch": 62.147...      NaN
# 2    {"register": "high", "reference_pitch": 61.456...      NaN
# 3    {"register": "high", "reference_pitch": 59.796...      NaN
# 4    {"register": "high", "reference_pitch": 61.077...      NaN
# ..                                                 ...      ...
# 759  {"reference_pitch": 58.50323955755315, "regist...      NaN
# 760  {"reference_pitch": 63.22744278433368, "regist...      NaN
# 761  {"reference_pitch": 62.02083459806798, "regist...      NaN
# 762  {"reference_pitch": 60.46645306886603, "regist...      NaN
# 763  {"reference_pitch": 61.2755138541487, "registe...      NaN
#
#      participant_group    block  propagate_failure  n_viable_trials  \
# 0              default  default              False                1
# 1              default  default              False                1
# 2              default  default              False                1
# 3              default  default              False                0
# 4              default  default              False                1
# ..                 ...      ...                ...              ...
# 759            default  default              False                0
# 760            default  default              False                0
# 761            default  default              False                0
# 762            default  default              False                0
# 763            default  default              False                0
#
#           class  object_type
# 0    CustomNode         Node
# 1    CustomNode         Node
# 2    CustomNode         Node
# 3    CustomNode         Node
# 4    CustomNode         Node
# ..          ...          ...
# 759  CustomNode         Node
# 760  CustomNode         Node
# 761  CustomNode         Node
# 762  CustomNode         Node
# 763  CustomNode         Node
#
# [764 rows x 33 columns]

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])
node_data["definition"].iloc[1]

print(node_data['definition'])
# Out:
# 0      {"register": "high", "reference_pitch": 63.455...
# 7      {"reference_pitch": 59.905623453969525, "regis...
# 12     {"reference_pitch": 63.37257169706941, "regist...
# 1      {"register": "high", "reference_pitch": 62.147...
# 8      {"reference_pitch": 62.71431526939736, "regist...
#                              ...
# 742    {"reference_pitch": 60.9008456904601, "registe...
# 746    {"reference_pitch": 63.31695363831831, "regist...
# 752    {"reference_pitch": 61.78532810216342, "regist...
# 754    {"reference_pitch": 61.960961592893284, "regis...
# 759    {"reference_pitch": 58.50323955755315, "regist...
# Name: definition, Length: 764, dtype: object

# %% [markdown]
# # Preprocess data

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])

# process node definition
mel_id = []
# register = []
trial_type = []
target_pitches = []
reference_pitch = []
target_note_durations = []

for i in range(len(node_data)):
    print()
    # definition = node_data["definition"].to_numpy()[i]
    # definition = literal_eval(definition)
    # definition = [d["content"] for d in definition if d["is_center"]][0]

    definition_str = node_data["definition"].iloc[i]  # Access the string directly
    print(definition_str)
    definition = json.loads(definition_str)  # Parse JSON string into dictionary
    # definition = [d["content"] for d in definition if d["is_center"]][0]
    
    # mel_id.append(definition["mel_id"])
    # register.append(definition["register"])
    trial_type.append(definition["trial_type"])
    target_pitches.append(definition["target_pitches"])
    reference_pitch.append(definition["reference_pitch"])
    target_intervals.append(definition["target_intervals"])

# node_data["mel_id"] = mel_id
# node_data["register"] = register
node_data["trial_type"] = trial_type
node_data["target_pitches"] = target_pitches
node_data["reference_pitch"] = reference_pitch
node_data["target_intervals"] = target_intervals
# Out:
# {"register": "high", "reference_pitch": 63.45586659211666, "max_interval2reference": 10, "max_interval_size": 5.5, "target_pitches": [71.97890171718197, 70.80946991384941, 61.649540345058185], "target_intervals": [-1.1694318033325573, -9.159929568791227], "target_intervals2reference": [8.523035125065313, 7.353603321732756, -1.8063262470584718], "num_target_pitches": 3, "trial_type": "source_trial", "reference_mode": "pitch_mode"}
#
# {"reference_pitch": 59
"num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 62.02083459806798, "register": "low", "target_pitches": [59.023243647086346, 59.37502983435296, 66.78808639699471], "target_intervals": [0.3517861872666117, 7.413056562641749], "target_intervals2reference": [-2.997590950981632, -2.64580476371502, 4.767251798926729], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"register": "high", "reference_pitch": 63.378337714592774, "max_interval2reference": 10, "max_interval_size": 5.5, "target_pitches": [71.51938703111418, 70.99519051988128, 64.85360940538851], "target_intervals": [-0.5241965112329012, -6.141581114492766], "target_intervals2reference": [8.141049316521404, 7.616852805288502, 1.4752716907957364], "num_target_pitches": 3, "trial_type": "source_trial", "reference_mode": "pitch_mode"}
#
# {"reference_pitch": 60.8075037843366, "register": "low", "target_pitches": [66.32124878790844, 65.43745624775232, 60.581165839609284], "target_intervals": [-0.8837925401561222, -4.856290408143039], "target_intervals2reference": [5.513745003571842, 4.629952463415719, -0.2263379447273195], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 60.62589912019543, "register": "low", "target_pitches": [66.31806163719301, 65.93129296288495, 60.81209564453197], "target_intervals": [-0.3867686743080654, -5.119197318352981], "target_intervals2reference": [5.692162516997591, 5.305393842689526, 0.18619652433654466], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 62.386989850069426, "register": "low", "target_pitches": [66.95894775243268, 66.98729564769789, 61.7717752808743], "target_intervals": [0.028347895265213197, -5.21552036682359], "target_intervals2reference": [4.571957902363252, 4.600305797628465, -0.6152145691951247], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 61.47970651050008, "register": "low", "target_pitches": [67.12766630001816, 66.67549563461709, 61.36842403112152], "target_intervals": [-0.45217066540107, -5.307071603495572], "target_intervals2reference": [5.647959789518083, 5.195789124117013, -0.11128247937855917], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 60.9008456904601, "register": "low", "target_pitches": [66.15131357088724, 65.99084823487601, 59.71944961577226], "target_intervals": [-0.16046533601122093, -6.271398619103756], "target_intervals2reference": [5.250467880427138, 5.090002544415917, -1.1813960746878394], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 63.31695363831831, "register": "low", "target_pitches": [68.31086550238614, 68.55213460727734, 61.9672662197689], "target_intervals": [0.24126910489120235, -6.584868387508436], "target_intervals2reference": [4.993911864067826, 5.235180968959028, -1.3496874185494079], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 61.78532810216342, "register": "low", "target_pitches": [66.65358001173212, 66.4077616839592, 60.31601867766966], "target_intervals": [-0.24581832777292334, -6.0917430062895335], "target_intervals2reference": [4.8682519095686985, 4.622433581795775, -1.4693094244937583], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 61.960961592893284, "register": "low", "target_pitches": [67.14630614716489, 66.83072839328892, 59.91162402741938], "target_intervals": [-0.31557775387598497, -6.919104365869536], "target_intervals2reference": [5.185344554271616, 4.869766800395631, -2.0493375654739054], "num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 58.50323955755315, "register": "low", "target_pitches": [63.640994965484175, 63.55972506296626, 56.09178029989278], "target_intervals": [-0.0812699025179171, -7.467944763073476], "target_intervals2reference": [5.137755407931024, 5.056485505413107, -2.4114592576603684], "num_target_pitches": 3, "trial_type": "node_trial"}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 38
#      36 node_data["target_pitches"] = target_pitches
#      37 node_data["reference_pitch"] = reference_pitch
# ---> 38 node_data["target_intervals"] = target_intervals
#
# File ~/.virtualenvs/data-analysis/lib/python3.12/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4296     self._setitem_array([key], value)
#    4297 else:
#    4298     # set column
# -> 4299     self._set_item(key, value)
#
# File ~/.virtualenvs/data-analysis/lib/python3.12/site-packages/pandas/core/frame.py:4512, in DataFrame._set_item(self, key, value)
#    4502 def _set_item(self, key, value) -> None:
#    4503     """
#    4504     Add series to DataFrame in specified column.
#    4505
#    (...)   4510     ensure homogeneity.
#    4511     """
# -> 4512     value, refs = self._sanitize_column(value)
#    4514     if (
#    4515         key in self.columns
#    4516         and value.ndim == 1
#    4517         and not isinstance(value.dtype, ExtensionDtype)
#    4518     ):
#    4519         # broadcast across multiple columns if necessary
#    4520         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.virtualenvs/data-analysis/lib/python3.12/site-packages/pandas/core/frame.py:5253, in DataFrame._sanitize_column(self, value)
#    5250     return _reindex_for_setitem(value, self.index)
#    5252 if is_list_like(value):
# -> 5253     com.require_length_match(value, self.index)
#    5254 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5255 if (
#    5256     isinstance(value, Index)
#    5257     and value.dtype == "object"
#    (...)   5260     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5261     # this deprecation
#
# File ~/.virtualenvs/data-analysis/lib/python3.12/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (765) does not match length of index (764)

# %%
node_data
# Out:
#       id  network_id  degree   trial_maker_id  \
# 0     17          17       0  imitation_chain
# 7     24          17       1  imitation_chain
# 12    29          17       2  imitation_chain
# 1     18          18       0  imitation_chain
# 8     25          18       1  imitation_chain
# ..   ...         ...     ...              ...
# 742  759         101       5  imitation_chain
# 746  763         101       6  imitation_chain
# 752  769         101       7  imitation_chain
# 754  771         101       8  imitation_chain
# 759  776         101       9  imitation_chain
#
#                                             definition  \
# 0    {"register": "high", "reference_pitch": 63.455...
# 7    {"reference_pitch": 59.905623453969525, "regis...
# 12   {"reference_pitch": 63.37257169706941, "regist...
# 1    {"register": "high", "reference_pitch": 62.147...
# 8    {"reference_pitch": 62.71431526939736, "regist...
# ..                                                 ...
# 742  {"reference_pitch": 60.9008456904601, "registe...
# 746  {"reference_pitch": 63.31695363831831, "regist...
# 752  {"reference_pitch": 61.78532810216342, "regist...
# 754  {"reference_pitch": 61.960961592893284, "regis...
# 759  {"reference_pitch": 58.50323955755315, "regist...
#
#                                                   seed    trial_type  \
# 0    {"register": "high", "reference_pitch": 63.455...  source_trial
# 7    {"reference_pitch": 59.905623453969525, "regis...    node_trial
# 12   {"reference_pitch": 63.37257169706941, "regist...    node_trial
# 1    {"register": "high", "reference_pitch": 62.147...  source_trial
# 8    {"reference_pitch": 62.71431526939736, "regist...    node_trial
# ..                                                 ...           ...
# 742  {"reference_pitch": 60.9008456904601, "registe...    node_trial
# 746  {"reference_pitch": 63.31695363831831, "regist...    node_trial
# 752  {"reference_pitch": 61.78532810216342, "regist...    node_trial
# 754  {"reference_pitch": 61.960961592893284, "regis...    node_trial
# 759  {"reference_pitch": 58.50323955755315, "regist...    node_trial
#
#                                         target_pitches  reference_pitch
# 0    [71.97890171718197, 70.80946991384941, 61.6495...        63.455867
# 7    [68.19130124093152, 66.7376844040187, 58.23899...        59.905623
# 12   [71.68087582862606, 70.3526284620336, 61.15191...        63.372572
# 1    [57.0874865808037, 55.159023703645786, 66.8177...        62.147933
# 8    [57.4134865885825, 55.0419626949176, 66.998792...        62.714315
# ..                                                 ...              ...
# 742  [66.15131357088724, 65.99084823487601, 59.7194...        60.900846
# 746  [68.31086550238614, 68.55213460727734, 61.9672...        63.316954
# 752  [66.65358001173212, 66.4077616839592, 60.31601...        61.785328
# 754  [67.14630614716489, 66.83072839328892, 59.9116...        61.960962
# 759  [63.640994965484175, 63.55972506296626, 56.091...        58.503240
#
# [764 rows x 9 columns]

# %% [markdown]
# # Export node data to csv

# %%
node_data.to_csv(f"{fname}_node_data.csv")

# %% [markdown]
# # Trial level data

# %%
# filter trials
trial_data = trials
trial_data = trial_data[trial_data["failed"] == False]

degrees = []

for i in range(len(trial_data)):
    current_node_id = trial_data.iloc[i]["origin_id"]
    current_nodes = node_data[node_data["id"] == current_node_id]
    current_degree = current_nodes["degree"].to_numpy()[0]
    # answer = d['listen_and_rate_trial_seed']['valence']
    # current_vertex_id = current_nodes["vertex_id"].to_numpy()[0]
    # current_dependent_vertex_ids = current_nodes["dependent_vertex_ids"].to_numpy()[0]
    degrees.append(current_degree)
    # vertex_ids.append(current_vertex_id)
    # dependent_vertex_ids.append(current_dependent_vertex_ids)

trial_data["degree"] = degrees

trial_data = trial_data[["id", "network_id", "degree", "trial_maker_id", "origin_id", "participant_id", "analysis"]]
trial_data = trial_data.sort_values(["network_id", "degree"])
# Out:
# /var/folders/v7/s8wj18ld78gdbf0vgx1ptf7r0000gr/T/ipykernel_7972/4239617211.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_data["degree"] = degrees

# %%
trial_data
# Out:
#         id  network_id  degree   trial_maker_id  origin_id  participant_id  \
# 209    604          17       0  imitation_chain         17              42
# 341    926          17       1  imitation_chain        452              61
# 564   1412          17       2  imitation_chain        607              84
# 663   1703          17       3  imitation_chain        860             104
# 1494  4321          17       4  imitation_chain        980             301
# ...    ...         ...     ...              ...        ...             ...
# 2555  7109         216       6  imitation_chain       3176             473
# 2616  7292         216       7  imitation_chain       3202             479
# 2666  7365         216       8  imitation_chain       3280             490
# 2704  7502         216       9  imitation_chain       3336             499
# 2746  7615         216      10  imitation_chain       3385             507
#
#                                                analysis
# 209   {"failed": false, "reason": "All good", "regis...
# 341   {"failed": false, "reason": "All good", "regis...
# 564   {"failed": false, "reason": "All good", "regis...
# 663   {"failed": false, "reason": "All good", "regis...
# 1494  {"failed": false, "reason": "All good", "regis...
# ...                                                 ...
# 2555  {"failed": false, "reason": "All good", "regis...
# 2616  {"failed": false, "reason": "All good", "regis...
# 2666  {"failed": false, "reason": "All good", "regis...
# 2704  {"failed": false, "reason": "All good", "regis...
# 2746  {"failed": false, "reason": "All good", "regis...
#
# [2195 rows x 7 columns]

# %% [markdown]
# # Export trial data to csv

# %%
trial_data.to_csv(f"{fname}_trial_data.csv")

# %% [markdown]
# # Experiment Cost and Demographics

# %%
participants = pd.read_csv(PATH + "participant.csv", low_memory=False)

# %%
valid_participants = participants[participants["complete"] == True]
valid_participants = valid_participants[valid_participants["failed"] == False]
experiment_summary = {
    "N_participants": valid_participants.shape[0],
    "cost": participants["base_pay"].sum() + participants["bonus"].sum()
}

experiment_summary
# Out:
# {'N_participants': 16, 'cost': 0.0}
